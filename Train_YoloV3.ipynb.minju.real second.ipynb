# %%
import cv2
import numpy as np

# %%
def yolo(frame, size, score_threshold, nms_threshold):
    # YOLO 네트워크 불러오기
    net = cv2.dnn.readNet(f"yolov3_training_best.weights", "yolov3_training.cfg")
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # 클래스의 갯수만큼 랜덤 RGB 배열을 생성
    colors = np.random.uniform(0, 255, size=(len(classes), 3))

    # 이미지의 높이, 너비, 채널 받아오기
    height, width, channels = frame.shape

    # 네트워크에 넣기 위한 전처리
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (size, size), (0, 0, 0), True, crop=False)

    # 전처리된 blob 네트워크에 입력
    net.setInput(blob)

    # 결과 받아오기
    outs = net.forward(output_layers)

    # 각각의 데이터를 저장할 빈 리스트
    class_ids = []
    confidences = []
    boxes = []

    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.1:
                # 탐지된 객체의 너비, 높이 및 중앙 좌표값 찾기
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # 객체의 사각형 테두리 중 좌상단 좌표값 찾기
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    # 후보 박스(x, y, width, height)와 confidence(상자가 물체일 확률) 출력
    print(f"boxes: {boxes}")
    print(f"confidences: {confidences}")

    # Non Maximum Suppression (겹쳐있는 박스 중 confidence 가 가장 높은 박스를 선택)
    indexes = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=score_threshold, nms_threshold=nms_threshold)
    
    # 후보 박스 중 선택된 박스의 인덱스 출력
    print(f"indexes: ", end='')
    for index in indexes:
        print(index, end=' ')
    print("\n\n============================== classes ==============================")

    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            class_name = classes[class_ids[i]]
            label = f"{class_name} {confidences[i]:.2f}"
            color = colors[class_ids[i]]

            # 사각형 테두리 그리기 및 텍스트 쓰기
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            cv2.rectangle(frame, (x - 1, y), (x + len(class_name) * 13 + 65, y - 25), color, -1)
            cv2.putText(frame, label, (x, y - 8), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 2)
            
            # 탐지된 객체의 정보 출력
            print(f"[{class_name}({i})] conf: {confidences[i]} / x: {x} / y: {y} / width: {w} / height: {h}")

    return frame

# %%
# 클래스 리스트
classes = ["fire"]

# 이미지 경로
img = "C:\\Users\\jaa13\\Desktop\\fire\\valid\\valid\\fire_21.jpg"

# 이미지 읽어오기
frame = cv2.imread(img)

# 입력 사이즈 리스트 (Yolo 에서 사용되는 네크워크 입력 이미지 사이즈)
size_list = [200, 416, 608]

frame = yolo(frame=frame, size=size_list[2], score_threshold=0.4, nms_threshold=0.4)
cv2.imshow("Output_Yolo", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# boxes: [[477, -9, 433, 572]]
# confidences: [0.6931588053703308]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.6931588053703308 / x: 477 / y: -9 / width: 433 / height: 572

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
def yolo(frame, size, score_threshold, nms_threshold):
    # YOLO 네트워크 불러오기
    net = cv2.dnn.readNet(f"model_data/yolov3_training_best.weights", "model_data/yolov3_training.cfg")
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # 클래스의 갯수만큼 랜덤 RGB 배열을 생성
    colors = np.random.uniform(0, 255, size=(len(classes), 3))

    # 이미지의 높이, 너비, 채널 받아오기    
    check, frame = cam.read()
    height, width, channels = frame.shape

    # 네트워크에 넣기 위한 전처리
    blob = cv2.dnn.blobFromImage(frame, 0.00392, (size, size), (0, 0, 0), True, crop=False)

    # 전처리된 blob 네트워크에 입력
    net.setInput(blob)

    # 결과 받아오기
    outs = net.forward(output_layers)

    # 각각의 데이터를 저장할 빈 리스트
    class_ids = []
    confidences = []
    boxes = []

    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence > 0.1:
                # 탐지된 객체의 너비, 높이 및 중앙 좌표값 찾기
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # 객체의 사각형 테두리 중 좌상단 좌표값 찾기
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    # 후보 박스(x, y, width, height)와 confidence(상자가 물체일 확률) 출력
    print(f"boxes: {boxes}")
    print(f"confidences: {confidences}")

    # Non Maximum Suppression (겹쳐있는 박스 중 confidence 가 가장 높은 박스를 선택)
    indexes = cv2.dnn.NMSBoxes(boxes, confidences, score_threshold=score_threshold, nms_threshold=nms_threshold)
    
    # 후보 박스 중 선택된 박스의 인덱스 출력
    print(f"indexes: ", end='')
    for index in indexes:
        print(index, end=' ')
    print("\n\n============================== classes ==============================")

    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            class_name = classes[class_ids[i]]
            label = f"{class_name} {confidences[i]:.2f}"
            color = colors[class_ids[i]]

            # 사각형 테두리 그리기 및 텍스트 쓰기
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            cv2.rectangle(frame, (x - 1, y), (x + len(class_name) * 13 + 65, y - 25), color, -1)
            cv2.putText(frame, label, (x, y - 8), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 2)
            
            # 탐지된 객체의 정보 출력
            print(f"[{class_name}({i})] conf: {confidences[i]} / x: {x} / y: {y} / width: {w} / height: {h}")

    return frame

# %%
# 클래스 리스트
classes = ["fire"]

cam = cv2.VideoCapture(0)

# 입력 사이즈 리스트 (Yolo 에서 사용되는 네크워크 입력 이미지 사이즈)
size_list = [320, 416, 608]

while True:
    frame = yolo(frame=cam, size=size_list[2], score_threshold=0.4, nms_threshold=0.4)
    cv2.imshow("Output_Yolo", frame)
    key = cv2.waitKey(1)
    if key == 27:
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# boxes: [[254, 37, 333, 400]]
# confidences: [0.29966577887535095]
# indexes:
#
# ============================== classes ==============================
# boxes: [[271, 46, 366, 231]]
# confidences: [0.8743358850479126]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.8743358850479126 / x: 271 / y: 46 / width: 366 / height: 231
# boxes: [[285, 44, 334, 237]]
# confidences: [0.7299063205718994]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.7299063205718994 / x: 285 / y: 44 / width: 334 / height: 237
# boxes: [[280, 46, 346, 231]]
# confidences: [0.8555728793144226]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.8555728793144226 / x: 280 / y: 46 / width: 346 / height: 231
# boxes: [[278, 48, 350, 227]]
# confidences: [0.8336874842643738]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.8336874842643738 / x: 278 / y: 48 / width: 350 / height: 227
# boxes: [[266, 45, 372, 231]]
# confidences: [0.5534572005271912]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.5534572005271912 / x: 266 / y: 45 / width: 372 / height: 231
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[255, 231, 262, 135]]
# confidences: [0.48764997720718384]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.48764997720718384 / x: 255 / y: 231 / width: 262 / height: 135
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[304, 264, 240, 147]]
# confidences: [0.6132428050041199]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.6132428050041199 / x: 304 / y: 264 / width: 240 / height: 147
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[104, 162, 225, 121]]
# confidences: [0.294887900352478]
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[1, 188, 488, 202]]
# confidences: [0.954829752445221]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.954829752445221 / x: 1 / y: 188 / width: 488 / height: 202
# boxes: [[0, 178, 505, 214]]
# confidences: [0.7822815775871277]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.7822815775871277 / x: 0 / y: 178 / width: 505 / height: 214
# boxes: [[-23, 191, 425, 184]]
# confidences: [0.8532405495643616]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.8532405495643616 / x: -23 / y: 191 / width: 425 / height: 184
# boxes: [[8, 149, 415, 243]]
# confidences: [0.792147159576416]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.792147159576416 / x: 8 / y: 149 / width: 415 / height: 243
# boxes: [[95, 192, 253, 154]]
# confidences: [0.4684150815010071]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.4684150815010071 / x: 95 / y: 192 / width: 253 / height: 154
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[245, 29, 360, 218]]
# confidences: [0.28297844529151917]
# indexes:
#
# ============================== classes ==============================
# boxes: [[233, 34, 384, 208]]
# confidences: [0.28674623370170593]
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[114, 221, 274, 148]]
# confidences: [0.9246410727500916]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.9246410727500916 / x: 114 / y: 221 / width: 274 / height: 148
# boxes: [[-46, 195, 543, 206]]
# confidences: [0.9831826090812683]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.9831826090812683 / x: -46 / y: 195 / width: 543 / height: 206
# boxes: [[94, 38, 509, 397]]
# confidences: [0.904217541217804]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.904217541217804 / x: 94 / y: 38 / width: 509 / height: 397
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[248, 50, 401, 230]]
# confidences: [0.7983399629592896]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.7983399629592896 / x: 248 / y: 50 / width: 401 / height: 230
# boxes: []
# confidences: []
# indexes:
#
# ============================== classes ==============================
# boxes: [[241, 39, 412, 250]]
# confidences: [0.5619555115699768]
# indexes: [0]
#
# ============================== classes ==============================
# [fire(0)] conf: 0.5619555115699768 / x: 241 / y: 39 / width: 412 / height: 250
# boxes: [[238, 38, 357, 254]]
# confidences: [0.2727315127849579]
# indexes:
#
# ============================== classes ==============================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6d3a3b2f77e4> in <module>
#      14         break
#      15
# ---> 16 cap.release()
#      17 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined
